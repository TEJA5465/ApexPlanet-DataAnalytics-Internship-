# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("cleaned_dataset.csv")

df.head()
# Out:
#    order_id  order_date customer_name region         category sub_category  \
# 0         1  2025-01-05         Alice   East        Furniture        Chair
# 1         2  2025-01-07           Bob   West       Technology       Laptop
# 2         3  2025-01-10       Charlie  South  Office Supplies        Paper
# 3         4  2025-01-12         David  North        Furniture        Table
# 4         5  2025-01-15           Eva   East       Technology        Phone
#
#    sales  profit  quantity
# 0    250      40         2
# 1   1200     200         1
# 2     50      10         5
# 3    450      70         1
# 4    800     150         2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       10 non-null     int64
#  1   order_date     10 non-null     object
#  2   customer_name  10 non-null     object
#  3   region         10 non-null     object
#  4   category       10 non-null     object
#  5   sub_category   10 non-null     object
#  6   sales          10 non-null     int64
#  7   profit         10 non-null     int64
#  8   quantity       10 non-null     int64
# dtypes: int64(4), object(5)
# memory usage: 852.0+ bytes

# %%
df.describe()
# Out:
#        order_id        sales      profit  quantity
# count  10.00000    10.000000   10.000000  10.00000
# mean    5.50000   406.500000   74.300000   2.90000
# std     3.02765   375.618379   65.306202   2.84605
# min     1.00000    25.000000    5.000000   1.00000
# 25%     3.25000   100.000000   17.500000   1.00000
# 50%     5.50000   325.000000   65.000000   2.00000
# 75%     7.75000   562.500000  110.000000   3.50000
# max    10.00000  1200.000000  200.000000  10.00000

# %%
sales_category = df.groupby("category")["sales"].sum()

sales_category.plot(kind="bar", color="skyblue", figsize=(6,4))

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.tight_layout()

plt.savefig("../charts/sales_by_category.png")

plt.show()

# %%
profit_region = df.groupby("region")["profit"].sum()

profit_region.plot(
    kind="pie",
    autopct="%1.1f%%",
    figsize=(6,6)
)

plt.title("Profit by Region")

plt.ylabel("")

plt.savefig("../charts/profit_by_region.png")

plt.show()

# %%
correlation = df[["sales", "profit", "quantity"]].corr()

print(correlation)

sns.heatmap(correlation, annot=True, cmap="Blues")

plt.title("Correlation Heatmap")

plt.savefig("../charts/correlation_heatmap.png")

plt.show()
# Out:
#              sales    profit  quantity
# sales     1.000000  0.989327 -0.600597
# profit    0.989327  1.000000 -0.617355
# quantity -0.600597 -0.617355  1.000000
